# %%
import pandas as pd

# %%
x = pd.read_csv('X_train.csv')

# %%
x.head
# Out:
# <bound method NDFrame.head of           row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0            0_0          0                   0       -0.75853       -0.63435
# 1            0_1          0                   1       -0.75853       -0.63434
# 2            0_2          0                   2       -0.75853       -0.63435
# 3            0_3          0                   3       -0.75852       -0.63436
# 4            0_4          0                   4       -0.75852       -0.63435
# 5            0_5          0                   5       -0.75853       -0.63439
# 6            0_6          0                   6       -0.75853       -0.63441
# 7            0_7          0                   7       -0.75852       -0.63444
# 8            0_8          0                   8       -0.75851       -0.63445
# 9            0_9          0                   9       -0.75851       -0.63443
# 10          0_10          0                  10       -0.75848       -0.63443
# ...

# %%
import matplotlib.pyplot as plt

# %%
x_s_id = x['series_id'].unique()

# %%
x_s_id

x.iloc[1][2]
# Out:
# 1

# %%
ox_,oy_,oz_,ow_,avx_,avy_,avz_,lax_,lay_,laz_=[],[],[],[],[],[],[],[],[],[]
for i in range(1,100):
    xmn = []
    ox = []
    oy=[]
    oz=[]
    ow=[]
    avx,avy,avz = [],[],[]
    lax,lay,laz = [],[],[]
    for j in range(len(x)):
        
       
        if x.iloc[j][1]==i:
            xmn.append(x.iloc[j][2])
            ox.append(x.iloc[j][3])
            oy.append(x.iloc[j][4])
            oz.append(x.iloc[j][5])
            ow.append(x.iloc[j][6])
            avx.append(x.iloc[j][7])
            avy.append(x.iloc[j][8])
            avz.append(x.iloc[j][9])
            lax.append(x.iloc[j][10])
            lay.append(x.iloc[j][11])
            laz.append(x.iloc[j][12])
    ox_.append(ox)
    oy_.append(oy)
    oz_.append(oz)
    ow_.append(ow)
    avx_.append(avx)
    avy_.append(avy)
    avz_.append(avz)
    lax_.append(lax)
    lay_.append(lay)
    laz_.append(laz)

# %%
import concurrent.futures

# %%
ox_,oy_,oz_,ow_,avx_,avy_,avz_,lax_,lay_,laz_=[],[],[],[],[],[],[],[],[],[]
xmn = []
ox = []
oy=[]
oz=[]
ow=[]
avx,avy,avz = [],[],[]
lax,lay,laz = [],[],[]
for j in range(len(x)):
        if x.iloc[j][1]==1:
            xmn.append(x.iloc[j][2])
            ox.append(x.iloc[j][3])
            oy.append(x.iloc[j][4])
            oz.append(x.iloc[j][5])
            ow.append(x.iloc[j][6])
            avx.append(x.iloc[j][7])
            avy.append(x.iloc[j][8])
            avz.append(x.iloc[j][9])
            lax.append(x.iloc[j][10])
            lay.append(x.iloc[j][11])
            laz.append(x.iloc[j][12])
ox_.append(ox)
oy_.append(oy)
oz_.append(oz)
ow_.append(ow)
avx_.append(avx)
avy_.append(avy)
avz_.append(avz)
lax_.append(lax)
lay_.append(lay)
laz_.append(laz)

# %%
graphs = [ox,oy,oz,ow,avx,avy,avz,lax,lay,laz]
for i in range(0,10):
    fig,ax = plt.subplots()
    ax.plot(xmn,graphs[i])
    ax.grid()

# %%
xmn = []
ox = []
oy=[]
oz=[]
ow=[]
avx,avy,avz = [],[],[]
lax,lay,laz = [],[],[]
for j in range(len(x)):
        if x.iloc[j][1]==2:
            xmn.append(x.iloc[j][2])
            ox.append(x.iloc[j][3])
            oy.append(x.iloc[j][4])
            oz.append(x.iloc[j][5])
            ow.append(x.iloc[j][6])
            avx.append(x.iloc[j][7])
            avy.append(x.iloc[j][8])
            avz.append(x.iloc[j][9])
            lax.append(x.iloc[j][10])
            lay.append(x.iloc[j][11])
            laz.append(x.iloc[j][12])
ox_.append(ox)
oy_.append(oy)
oz_.append(oz)
ow_.append(ow)
avx_.append(avx)
avy_.append(avy)
avz_.append(avz)
lax_.append(lax)
lay_.append(lay)
laz_.append(laz)

# %%
print(ox_)
# Out:
# [[-0.95896, -0.9589, -0.9588899999999999, -0.95888, -0.95888, -0.95896, -0.95895, -0.95891, -0.95885, -0.95886, -0.95885, -0.95886, -0.9588399999999999, -0.95875, -0.9587100000000001, -0.9587, -0.95873, -0.9586899999999999, -0.9587100000000001, -0.95873, -0.9587399999999999, -0.9587600000000001, -0.9587600000000001, -0.9587899999999999, -0.9588399999999999, -0.9588200000000001, -0.95878, -0.95873, -0.9587100000000001, -0.95878, -0.9587700000000001, -0.9587200000000001, -0.95867, -0.95863, -0.9585899999999999, -0.95857, -0.95857, -0.9585, -0.95845, -0.95841, -0.9584, -0.95842, -0.95845, -0.9584600000000001, -0.9584799999999999, -0.9584799999999999, -0.9585100000000001, -0.9585600000000001, -0.9586, -0.95862, -0.95863, -0.95863, -0.95863, -0.95867, -0.95867, -0.95865, -0.95863, -0.9586100000000001, -0.9585899999999999, -0.9585799999999999, -0.95857, -0.95854, -0.9585299999999999, -0.9585299999999999, -0.9585299999999999, -0.95854, -0.9585799999999999, -0.9586100000000001, -0.95863, -0.
# ...

# %%
print(oy_)
# Out:
# [[0.24074, 0.24079, 0.24076, 0.24076, 0.24079, 0.24081999999999998, 0.24093, 0.24105, 0.24119000000000002, 0.24123000000000003, 0.24139000000000002, 0.24151, 0.24161, 0.24176, 0.24181, 0.24181, 0.24172, 0.24188, 0.24183000000000002, 0.2417, 0.24153000000000002, 0.24149, 0.24141999999999997, 0.24131, 0.24118, 0.24106999999999998, 0.24106, 0.24106999999999998, 0.24106, 0.24101, 0.24111999999999997, 0.24126, 0.24134, 0.24135, 0.24149, 0.24165, 0.24176, 0.24178000000000002, 0.24185, 0.24191, 0.24191, 0.24198000000000003, 0.24193, 0.2419, 0.24181999999999998, 0.24179, 0.24168, 0.2416, 0.24155, 0.24144000000000002, 0.24139000000000002, 0.2414, 0.24144000000000002, 0.24140999999999999, 0.24148000000000003, 0.24161999999999997, 0.24174, 0.24181, 0.24193, 0.24208000000000002, 0.24220999999999998, 0.24229, 0.24235, 0.24236, 0.24236999999999997, 0.24245999999999998, 0.24238, 0.2423, 0.2422, 0.24220999999999998, 0.24209, 0.242, 0.24191, 0.24183000000000002, 0.24176999999999998, 0.24175, 0.24175,
# ...

# %%
print(oz_)
# Out:
# [[0.030757999999999997, 0.030786, 0.030807, 0.030742000000000002, 0.030706999999999998, 0.030674, 0.030685000000000004, 0.030729000000000003, 0.030737999999999998, 0.030688, 0.030611000000000003, 0.030545, 0.030504000000000003, 0.030693, 0.030885000000000003, 0.030886, 0.030820999999999998, 0.030910000000000003, 0.031063999999999998, 0.031081, 0.031013, 0.031137, 0.031312, 0.031356, 0.03121, 0.031239999999999997, 0.031387, 0.031513, 0.031474, 0.031339, 0.031457, 0.031577999999999995, 
# [[2.2526, 2.9762, 1.6803, 0.22349000000000002, -0.92942, 0.90256, 1.4673, 1.8202, 1.4067, -1.3576, -2.1492, 1.3572, 3.1775, -1.0471, -0.23744, 0.13757, 1.1903, 2.2982, -0.17418, 0.42482, 0.90017, 1.7861, 2.4726, 1.6480000000000001, 0.65875, 3.2962, 4.6072, 3.1564, 2.1587, 2.5916, 4.6981, 4.4942, 4.8925, 5.0326, 2.727, 4.0952, 6.6671, 5.7586, 5.8606, 4.0669, 3.7849, 6.685, 6.1343, 5.0056, 4.3994, 5.5014, 5.7219, 5.2318, 4.4405, 3.8372, 4.5915, 4.2171, 3.2163, 2.8627, 3.3966, 2.766, 3.0622, 2.6441, 1.8293, 2.1869, 1.8782, 2.5673, 1.0299, 1.5782, 1.175, -0.0020685, 0.7628699999999999, 0.76345, -0.067929, 0.39757, 0.1209, 0.022524000000000002, 0.6755800000000001, -0.27924, 1.3502, 1.4338, 0.57531, 0.58158, 1.0007, 2.7342, 3.0036, 1.8803, 2.8396, 2.6537, 3.6899, 4.8364, 2.6985, 3.3589, 4.5275, 4.9408, 5.2014, 4.1088, 3.9994, 4.5847, 5.4095, 5.0356, 4.4254, 2.9913, 4.9794, 4.6269, 5.0292, 3.2184, 2.6531, 4.5551, 4.6605, 4.1799, 3.4723, 2.6164, 3.0943, 4.1645, 4.1176, 2.8291, 1.5438, 5.016,
# ...

# %%
print(laz_)
# Out:
# [[-8.9503, -5.4953, -7.3061, -11.491, -12.298, -10.027999999999999, -9.2081, -9.2065, -11.823, -16.928, -15.122, -7.2327, -2.7449, -5.7714, -9.1993, -11.917, -11.155, -8.4679, -8.5302, -8.7981, -7.9001, -9.3731, -11.01, -12.15, -10.481, -5.2027, -5.5515, -11.338, -14.499, -11.783, -7.2105, -6.1684, -7.1071, -10.27, -13.386, -12.352, -7.2036, -4.8180000000000005, -4.9372, -9.2611, -13.039000000000001, -9.8833, -8.517000000000001, -9.4473, -11.177999999999999, -10.868, -9.5734, -9.5803, -9.2514, -7.2497, -5.7028, -7.321000000000001, -10.177999999999999, -10.248, -8.844, -8.42, -9.073, -10.675999999999998, -11.594000000000001, -10.22, -8.9289, -8.6342, -9.6573, -9.7452, -10.968, -10.972999999999999, -9.4129, -7.3309, -8.2586, -9.4504, -10.021, -10.243, -8.9576, -9.6533, -8.5259, -9.6082, -11.832, -12.142000000000001, -10.016, -7.5229, -7.837999999999999, -9.9955, -10.56, -9.8579, -7.6207, -6.4544, -8.6856, -9.7194, -10.145, -9.8723, -9.0708, -9.2091, -9.2342, -9.4379, -8.193999999999999
# ...

# %%
for i in range(101,200):
    xmn = []
    ox = []
    oy=[]
    oz=[]
    ow=[]
    avx,avy,avz = [],[],[]
    lax,lay,laz = [],[],[]
    for j in range(len(x)):
        
       
        if x.iloc[j][1]==i:
            xmn.append(x.iloc[j][2])
            ox.append(x.iloc[j][3])
            oy.append(x.iloc[j][4])
            oz.append(x.iloc[j][5])
            ow.append(x.iloc[j][6])
            avx.append(x.iloc[j][7])
            avy.append(x.iloc[j][8])
            avz.append(x.iloc[j][9])
            lax.append(x.iloc[j][10])
            lay.append(x.iloc[j][11])
            laz.append(x.iloc[j][12])
    ox_.append(ox)
    oy_.append(oy)
    oz_.append(oz)
    ow_.append(ow)
    avx_.append(avx)
    avy_.append(avy)
    avz_.append(avz)
    lax_.append(lax)
    lay_.append(lay)
    laz_.append(laz)
